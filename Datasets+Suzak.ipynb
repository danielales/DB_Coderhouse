# %% [markdown]
# <a href="https://colab.research.google.com/github/danielales/DB_Coderhouse/blob/main/Datasets%2BSuzak.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Presentación
# Datasets de Daniel Suzak
#
# *Data Science I: Fundamentos para la Ciencia de Datos*
#
# Comisión: 61615
#
# Fecha: 03/08/2024

# %% [markdown]
# ###Primero lo primero...

# %%
import pandas as pd

# %%
from google.colab import drive
import os
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
from google.colab import drive
# %cd '/content/gdrive/MyDrive'
# Out:
# /content/gdrive/MyDrive

# %% [markdown]
# ###Dataset 1: Películas

# %%
file_path_1 = ('/content/gdrive/MyDrive/imdb_movies.csv')
df_1 = pd.read_csv (file_path_1)
df_1.head()
# Out:
#                          names       date_x  score  \
# 0                    Creed III  03/02/2023    73.0
# 1     Avatar: The Way of Water  12/15/2022    78.0
# 2  The Super Mario Bros. Movie  04/05/2023    76.0
# 3                      Mummies  01/05/2023    70.0
# 4                    Supercell  03/17/2023    61.0
#
#                                            genre  \
# 0                                  Drama, Action
# 1             Science Fiction, Adventure, Action
# 2  Animation, Adventure, Family, Fantasy, Comedy
# 3  Animation, Comedy, Family, Adventure, Fantasy
# 4                                         Action
#
#                                             overview  \
# 0  After dominating the boxing world, Adonis Cree...
# 1  Set more than a decade after the events of the...
# 2  While working underground to fix a water main,...
# 3  Through a series of unfortunate events, three ...
# 4  Good-hearted teenager William always lived in ...
#
# ...

# %% [markdown]
# ###Dataset 2: Vuelos
# link: https://datos.yvera.gob.ar/dataset/conectividad-aerea/archivo/aab49234-28c9-48ab-a978-a83485139290

# %%
file_path_2 = ('/content/gdrive/MyDrive/conectividad_aerea.csv')
df_2 = pd.read_csv (file_path_2)
df_2.head()
# Out:
#   indice_tiempo clasificacion_vuelo clase_vuelo              aerolinea  \
# 0    2017-01-01            Cabotaje  No Regular    Andes Líneas Aéreas
# 1    2017-01-01            Cabotaje  No Regular    Andes Líneas Aéreas
# 2    2017-01-01            Cabotaje  No Regular    Andes Líneas Aéreas
# 3    2017-01-01            Cabotaje     Regular  Aerolíneas Argentinas
# 4    2017-01-01            Cabotaje     Regular  Aerolíneas Argentinas
#
#   origen_oaci                          origen_aeropuerto  \
# 0        SAAV                  Aeropuerto de Sauce Viejo
# 1        SASA    Aeropuerto Int. Martín Miguel de Güemes
# 2        SAZS       Aeropuerto Int. Tte. Luis Candelaria
# 3        SAAR  Aeropuerto Int. de Rosario Islas Malvinas
# 4        SAAR  Aeropuerto Int. de Rosario Islas Malvinas
#
#           origen_localidad origen_provincia origen_pais origen_continente  \
# 0                 Santa Fe         Santa Fe   Argentina   América del Sur
# ...

# %% [markdown]
# ###Dataset 3: Alojamiento
# link: https://datos.yvera.gob.ar/dataset/padron-unico-nacional-alojamiento/archivo/01d23e57-ba58-48ed-a1c9-e1604ae78a1d

# %%
file_path_3 = ('/content/gdrive/MyDrive/alojamiento.csv')
df_3 = pd.read_csv(file_path_3, encoding='ISO-8859-1')
df_3.head()
# Out:
#    indice_tiempo        region ruta_natural  provincia_codigo  \
# 0           2020  Buenos Aires        Delta                 6
# 1           2020  Buenos Aires        Delta                 6
# 2           2020  Buenos Aires        Delta                 6
# 3           2020  Buenos Aires        Delta                 6
# 4           2020  Buenos Aires        Delta                 6
#
#   provincia_nombre departamento_partido localidad  \
# 0     Buenos Aires             Baradero  Baradero
# 1     Buenos Aires             Baradero  Baradero
# 2     Buenos Aires             Baradero  Baradero
# 3     Buenos Aires             Baradero  Baradero
# 4     Buenos Aires             Baradero  Baradero
#
#                              clasificacion              tipo  \
# 0  Albergue municipal / complejo deportivo  Otros colectivos
# 1                      Cabañas / bungalows     Parahoteleros
# 2          Conjunto de unidades turisticas  Otros colectivos
# ...
